# %% [markdown]
# <a href="https://colab.research.google.com/github/silviolima07/Clusters/blob/main/Solar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#
import warnings
warnings.filterwarnings("ignore")

from sklearn import preprocessing, cluster
import yellowbrick

from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer


# %matplotlib inline

# %%
def hist_plot(df,var,bins=20):
  return df.hist(column = var, figsize=(7,6), bins=bins);

# %%
def order_cluster(cluster_field_name, target_field_name,df,ascending):
    new_cluster_field_name = 'new_' + cluster_field_name
    df_new = df.groupby(cluster_field_name)[target_field_name].mean().reset_index()
    df_new = df_new.sort_values(by=target_field_name,ascending=ascending).reset_index(drop=True)
    df_new['index'] = df_new.index
    df_final = pd.merge(df,df_new[[cluster_field_name,'index']], on=cluster_field_name)
    df_final = df_final.drop([cluster_field_name],axis=1)
    df_final = df_final.rename(columns={"index":cluster_field_name})
    return df_final

# %%
df = pd.read_csv('/content/base_municipio.csv', encoding='latin-1')

# %%
df
# Out:
#       Código                  Município  UF  Área (km²)  \
# 0     130230                     Jutaí   AM     69857.4
# 1     130380  São Gabriel da Cachoeira   AM    109669.0
# 2     291110      Formosa do Rio Preto   BA     16514.3
# 3     500560                   Miranda   MS      5494.5
# 4     431730   Santa Vitória do Palmar   RS      5242.7
# ...      ...                        ...  ..         ...
# 5502  431848     São José do Hortêncio   RS        64.5
# 5503  432330               Vila Flores   RS       125.0
# 5504  431162           Lindolfo Collor   RS        31.8
# 5505  290290            Barra do Choça   BA       781.3
# 5506  431695     Santa Maria do Herval   RS       132.6
#
#       Densidade demográfica, 2000  Distância à capital (km)  \
# 0                             0.3                749.232205
# 1                             0.3                851.225150
# 2                             1.1                756.981922
# 3                             4.2                181.846641
# 4                             6.4                436.821147
# ...                           ...                       ...
# 5502                         52.4                 56.152137
# 5503                         24.7                133.275166
# 5504                        142.9                 48.490606
# 5505                         52.2                307.875581
# 5506                         44.4                 63.693160
#
#       Esperança de vida ao nascer, 2000  \
# 0                                 61.25
# 1                                 68.60
# 2                                 64.30
# 3                                 65.05
# 4                                 68.63
# ...                                 ...
# 5502                              76.82
# 5503                              75.51
# 5504                              75.81
# 5505                              63.50
# 5506                              75.81
#
#       Mortalidade até um ano de idade, 2000  Taxa de fecundidade total, 2000  \
# 0                                     63.34                             5.74
# 1                                     34.20                             3.21
# 2                                     44.73                             3.49
# 3                                     41.64                             3.11
# 4                                     24.70                             2.85
# ...                                     ...                              ...
# 5502                                   8.37                             2.18
# 5503                                  10.45                             2.01
# 5504                                   9.96                             2.26
# 5505                                  47.63                             3.26
# 5506                                   9.96                             2.17
#
#       Percentual de pessoas de 25 anos ou mais analfabetas, 2000  ...  \
# 0                                                 50.62           ...
# 1                                                 33.99           ...
# 2                                                 40.20           ...
# 3                                                 23.02           ...
# 4                                                 10.70           ...
# ...                                                 ...           ...
# 5502                                               3.15           ...
# 5503                                               6.00           ...
# 5504                                               4.60           ...
# 5505                                              49.27           ...
# 5506                                               3.85           ...
#
#       Taxa de alfabetização, 2000  \
# 0                           54.90
# 1                           76.85
# 2                           67.70
# 3                           83.40
# 4                           91.11
# ...                           ...
# 5502                        97.31
# 5503                        94.81
# 5504                        95.62
# 5505                        64.33
# 5506                        96.78
#
#       Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000  \
# 0                                                  2.08
# 1                                                  3.90
# 2                                                  2.90
# 3                                                  4.15
# 4                                                  5.70
# ...                                                 ...
# 5502                                               5.14
# 5503                                               5.31
# 5504                                               4.74
# 5505                                               1.75
# 5506                                               4.88
#
#       População de 25 anos ou mais de idade, 1991  \
# 0                                            4242
# 1                                            8762
# 2                                            5315
# 3                                            8317
# 4                                           16093
# ...                                           ...
# 5502                                         1374
# 5503                                         1553
# 5504                                         1179
# 5505                                         9187
# 5506                                         2553
#
#       População de 25 anos ou mais de idade, 2000  \
# 0                                            6210
# 1                                           11783
# 2                                            6935
# 3                                           10601
# 4                                           18638
# ...                                           ...
# 5502                                         2043
# 5503                                         1901
# 5504                                         2255
# 5505                                        17090
# 5506                                         3496
#
#       População de 65 anos ou mais de idade, 1991  \
# 0                                             171
# 1                                             938
# 2                                             583
# 3                                             898
# 4                                            1938
# ...                                           ...
# 5502                                          195
# 5503                                          184
# 5504                                           98
# 5505                                          991
# 5506                                          297
#
#       População de 65 anos ou mais de idade, 2000  População total, 1991  \
# 0                                             466                  14890
# 1                                            1096                  23140
# 2                                             777                  15418
# 3                                            1141                  20176
# 4                                            2605                  30056
# ...                                           ...                    ...
# 5502                                          296                   2383
# 5503                                          285                   2650
# 5504                                          173                   2543
# 5505                                         1693                  24844
# 5506                                          428                   4950
#
#       População total, 2000  População urbana, 2000  População rural, 2000
# 0                     22500                    7725                  14775
# 1                     29947                   12373                  17574
# 2                     18288                    9381                   8907
# 3                     23007                   12059                  10948
# 4                     33304                   27952                   5352
# ...                     ...                     ...                    ...
# 5502                   3387                    2093                   1294
# 5503                   3086                    1045                   2041
# 5504                   4414                    3418                    996
# 5505                  40818                   17721                  23097
# 5506                   5891                    4159                   1732
#
# [5507 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Código', 'Município', 'UF', 'Área (km²)',
#        'Densidade demográfica, 2000', 'Distância à capital (km)',
#        'Esperança de vida ao nascer, 2000',
#        'Mortalidade até um ano de idade, 2000',
#        'Taxa de fecundidade total, 2000',
#        'Percentual de pessoas de 25 anos ou mais analfabetas, 2000',
#        'Renda per Capita, 2000', 'Índice de Gini, 2000',
#        'Intensidade da indigência, 2000', 'Intensidade da pobreza, 2000',
#        'Índice de Desenvolvimento Humano Municipal, 2000',
#        'Taxa bruta de freqüência à escola, 2000',
#        'Taxa de alfabetização, 2000',
#        'Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000',
#        'População de 25 anos ou mais de idade, 1991',
#        'População de 25 anos ou mais de idade, 2000',
#        'População de 65 anos ou mais de idade, 1991',
#        'População de 65 anos ou mais de idade, 2000', 'População total, 1991',
#        'População total, 2000', 'População urbana, 2000',
#        'População rural, 2000'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Código                                                                   0
# Município                                                                0
# UF                                                                       0
# Área (km²)                                                               0
# Densidade demográfica, 2000                                              0
# Distância à capital (km)                                                 0
# Esperança de vida ao nascer, 2000                                        0
# Mortalidade até um ano de idade, 2000                                    0
# Taxa de fecundidade total, 2000                                          0
# Percentual de pessoas de 25 anos ou mais analfabetas, 2000               0
# Renda per Capita, 2000                                                   0
# Índice de Gini, 2000                                                     0
# Intensidade da indigência, 2000                                          0
# Intensidade da pobreza, 2000                                             0
# Índice de Desenvolvimento Humano Municipal, 2000                         0
# Taxa bruta de freqüência à escola, 2000                                  0
# Taxa de alfabetização, 2000                                              0
# Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000    0
# População de 25 anos ou mais de idade, 1991                              0
# População de 25 anos ou mais de idade, 2000                              0
# População de 65 anos ou mais de idade, 1991                              0
# População de 65 anos ou mais de idade, 2000                              0
# População total, 1991                                                    0
# População total, 2000                                                    0
# População urbana, 2000                                                   0
# População rural, 2000                                                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5507 entries, 0 to 5506
# Data columns (total 26 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Código                                                                 5507 non-null   int64
#  1   Município                                                              5507 non-null   object
#  2   UF                                                                     5507 non-null   object
#  3   Área (km²)                                                             5507 non-null   float64
#  4   Densidade demográfica, 2000                                            5507 non-null   float64
#  5   Distância à capital (km)                                               5507 non-null   float64
#  6   Esperança de vida ao nascer, 2000                                      5507 non-null   float64
#  7   Mortalidade até um ano de idade, 2000                                  5507 non-null   float64
#  8   Taxa de fecundidade total, 2000                                        5507 non-null   float64
#  9   Percentual de pessoas de 25 anos ou mais analfabetas, 2000             5507 non-null   float64
#  10  Renda per Capita, 2000                                                 5507 non-null   float64
#  11  Índice de Gini, 2000                                                   5507 non-null   float64
#  12  Intensidade da indigência, 2000                                        5507 non-null   float64
#  13  Intensidade da pobreza, 2000                                           5507 non-null   float64
#  14  Índice de Desenvolvimento Humano Municipal, 2000                       5507 non-null   float64
#  15  Taxa bruta de freqüência à escola, 2000                                5507 non-null   float64
#  16  Taxa de alfabetização, 2000                                            5507 non-null   float64
#  17  Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000  5507 non-null   float64
#  18  População de 25 anos ou mais de idade, 1991                            5507 non-null   int64
#  19  População de 25 anos ou mais de idade, 2000                            5507 non-null   int64
#  20  População de 65 anos ou mais de idade, 1991                            5507 non-null   int64
#  21  População de 65 anos ou mais de idade, 2000                            5507 non-null   int64
#  22  População total, 1991                                                  5507 non-null   int64
#  23  População total, 2000                                                  5507 non-null   int64
#  24  População urbana, 2000                                                 5507 non-null   int64
#  25  População rural, 2000                                                  5507 non-null   int64
# dtypes: float64(15), int64(9), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Manter apenas os dados referentes ao ano 2000

# %%
ano_1991 = [
       'População de 25 anos ou mais de idade, 1991',
       'População de 65 anos ou mais de idade, 1991',
       'População total, 1991']

# %%
df.drop(columns=ano_1991, inplace=True)

# %%
df
# Out:
#       Código                  Município  UF  Área (km²)  \
# 0     130230                     Jutaí   AM     69857.4
# 1     130380  São Gabriel da Cachoeira   AM    109669.0
# 2     291110      Formosa do Rio Preto   BA     16514.3
# 3     500560                   Miranda   MS      5494.5
# 4     431730   Santa Vitória do Palmar   RS      5242.7
# ...      ...                        ...  ..         ...
# 5502  431848     São José do Hortêncio   RS        64.5
# 5503  432330               Vila Flores   RS       125.0
# 5504  431162           Lindolfo Collor   RS        31.8
# 5505  290290            Barra do Choça   BA       781.3
# 5506  431695     Santa Maria do Herval   RS       132.6
#
#       Densidade demográfica, 2000  Distância à capital (km)  \
# 0                             0.3                749.232205
# 1                             0.3                851.225150
# 2                             1.1                756.981922
# 3                             4.2                181.846641
# 4                             6.4                436.821147
# ...                           ...                       ...
# 5502                         52.4                 56.152137
# 5503                         24.7                133.275166
# 5504                        142.9                 48.490606
# 5505                         52.2                307.875581
# 5506                         44.4                 63.693160
#
#       Esperança de vida ao nascer, 2000  \
# 0                                 61.25
# 1                                 68.60
# 2                                 64.30
# 3                                 65.05
# 4                                 68.63
# ...                                 ...
# 5502                              76.82
# 5503                              75.51
# 5504                              75.81
# 5505                              63.50
# 5506                              75.81
#
#       Mortalidade até um ano de idade, 2000  Taxa de fecundidade total, 2000  \
# 0                                     63.34                             5.74
# 1                                     34.20                             3.21
# 2                                     44.73                             3.49
# 3                                     41.64                             3.11
# 4                                     24.70                             2.85
# ...                                     ...                              ...
# 5502                                   8.37                             2.18
# 5503                                  10.45                             2.01
# 5504                                   9.96                             2.26
# 5505                                  47.63                             3.26
# 5506                                   9.96                             2.17
#
#       Percentual de pessoas de 25 anos ou mais analfabetas, 2000  ...  \
# 0                                                 50.62           ...
# 1                                                 33.99           ...
# 2                                                 40.20           ...
# 3                                                 23.02           ...
# 4                                                 10.70           ...
# ...                                                 ...           ...
# 5502                                               3.15           ...
# 5503                                               6.00           ...
# 5504                                               4.60           ...
# 5505                                              49.27           ...
# 5506                                               3.85           ...
#
#       Intensidade da pobreza, 2000  \
# 0                            69.64
# 1                            70.92
# 2                            65.16
# 3                            53.55
# 4                            38.22
# ...                            ...
# 5502                         32.32
# 5503                         31.42
# 5504                         30.94
# 5505                         40.71
# 5506                         26.43
#
#       Índice de Desenvolvimento Humano Municipal, 2000  \
# 0                                                0.533
# 1                                                0.673
# 2                                                0.646
# 3                                                0.724
# 4                                                0.799
# ...                                                ...
# 5502                                             0.815
# 5503                                             0.818
# 5504                                             0.805
# 5505                                             0.603
# 5506                                             0.806
#
#       Taxa bruta de freqüência à escola, 2000  Taxa de alfabetização, 2000  \
# 0                                       51.33                        54.90
# 1                                       68.38                        76.85
# 2                                       79.18                        67.70
# 3                                       76.35                        83.40
# 4                                       85.84                        91.11
# ...                                       ...                          ...
# 5502                                    71.58                        97.31
# 5503                                    86.00                        94.81
# 5504                                    72.43                        95.62
# 5505                                    75.63                        64.33
# 5506                                    69.68                        96.78
#
#       Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000  \
# 0                                                  2.08
# 1                                                  3.90
# 2                                                  2.90
# 3                                                  4.15
# 4                                                  5.70
# ...                                                 ...
# 5502                                               5.14
# 5503                                               5.31
# 5504                                               4.74
# 5505                                               1.75
# 5506                                               4.88
#
#       População de 25 anos ou mais de idade, 2000  \
# 0                                            6210
# 1                                           11783
# 2                                            6935
# 3                                           10601
# 4                                           18638
# ...                                           ...
# 5502                                         2043
# 5503                                         1901
# 5504                                         2255
# 5505                                        17090
# 5506                                         3496
#
#       População de 65 anos ou mais de idade, 2000  População total, 2000  \
# 0                                             466                  22500
# 1                                            1096                  29947
# 2                                             777                  18288
# 3                                            1141                  23007
# 4                                            2605                  33304
# ...                                           ...                    ...
# 5502                                          296                   3387
# 5503                                          285                   3086
# 5504                                          173                   4414
# 5505                                         1693                  40818
# 5506                                          428                   5891
#
#       População urbana, 2000  População rural, 2000
# 0                       7725                  14775
# 1                      12373                  17574
# 2                       9381                   8907
# 3                      12059                  10948
# 4                      27952                   5352
# ...                      ...                    ...
# 5502                    2093                   1294
# 5503                    1045                   2041
# 5504                    3418                    996
# 5505                   17721                  23097
# 5506                    4159                   1732
#
# [5507 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Código', 'Município', 'UF', 'Área (km²)',
#        'Densidade demográfica, 2000', 'Distância à capital (km)',
#        'Esperança de vida ao nascer, 2000',
#        'Mortalidade até um ano de idade, 2000',
#        'Taxa de fecundidade total, 2000',
#        'Percentual de pessoas de 25 anos ou mais analfabetas, 2000',
#        'Renda per Capita, 2000', 'Índice de Gini, 2000',
#        'Intensidade da indigência, 2000', 'Intensidade da pobreza, 2000',
#        'Índice de Desenvolvimento Humano Municipal, 2000',
#        'Taxa bruta de freqüência à escola, 2000',
#        'Taxa de alfabetização, 2000',
#        'Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000',
#        'População de 25 anos ou mais de idade, 2000',
#        'População de 65 anos ou mais de idade, 2000', 'População total, 2000',
#        'População urbana, 2000', 'População rural, 2000'],
#       dtype='object')

# %%
df.drop(columns=['Código'], inplace=True)

# %%
df.Município = df.Município.str.strip()

# %% [markdown]
# ## Distribuição da renda per capita pelas cidades

# %%
sns.set(palette='muted', color_codes=True, style='white')
fig, ax = plt.subplots(figsize=(12, 6))
sns.despine(left=True)
sns.distplot(df['Renda per Capita, 2000'], bins=30)
plt.show();

# %%
hist_plot(df,'Renda per Capita, 2000',10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb76f7a0a90>]],
#       dtype=object)

# %% [markdown]
# # Identifica-se na distribuição a existencia de 5 grupos:
# - Abaixo de 100
# - Entre 101 e 200
# - Entre 201 e 300
# - Entre 300 e 400
# - Acima de 400

# %%
renda = np.where((df['Renda per Capita, 2000'] > 0) & (df['Renda per Capita, 2000'] <100), "Abaixo de 100", 
                    np.where((df['Renda per Capita, 2000'] > 101) & (df['Renda per Capita, 2000'] <=200), "Entre 100 e 200",
                             np.where((df['Renda per Capita, 2000'] > 200) & (df['Renda per Capita, 2000'] <=300), "Entre 201 e 300",
                                      np.where((df['Renda per Capita, 2000'] > 300) & (df['Renda per Capita, 2000'] <= 400), "Entre 300 e 400",
                                               np.where((df['Renda per Capita, 2000'] > 400), "Acima de 400",'Abaixo de 100')))))

# %%
df['Faixa_renda'] = renda

# %% [markdown]
# # Distribuição da distância da cidade até a capital.
#
# ---

# %%
sns.set(palette='muted', color_codes=True, style='white')
fig, ax = plt.subplots(figsize=(12, 6))
sns.despine(left=True)
sns.distplot(df['Distância à capital (km)'], bins=30)
plt.show();

# %%
df['Distância à capital (km)'].describe()
# Out:
# count    5507.000000
# mean      253.212620
# std       163.210532
# min         0.000000
# 25%       121.858906
# 50%       228.262939
# 75%       358.072044
# max      1474.314590
# Name: Distância à capital (km), dtype: float64

# %%
distancia_capital = np.where((df['Distância à capital (km)'] > 0) & (df['Distância à capital (km)'] <121), "Abaixo de 120 km", 
                    np.where((df['Distância à capital (km)'] > 121) & (df['Distância à capital (km)'] <228), "Entre 121 e 228",
                             np.where((df['Distância à capital (km)'] > 228) & (df['Distância à capital (km)'] <358), "Entre 228 e 358",
                                      np.where(df['Distância à capital (km)'] > 358, 'Acima de 358', 'Abaixo de 120'))))

# %%
df['Distancia_capital'] = distancia_capital

# %%
df[['Município', 'Distância à capital (km)', 'Distancia_capital']]
# Out:
#                      Município  Distância à capital (km) Distancia_capital
# 0                        Jutaí                749.232205      Acima de 358
# 1     São Gabriel da Cachoeira                851.225150      Acima de 358
# 2         Formosa do Rio Preto                756.981922      Acima de 358
# 3                      Miranda                181.846641   Entre 121 e 228
# 4      Santa Vitória do Palmar                436.821147      Acima de 358
# ...                        ...                       ...               ...
# 5502     São José do Hortêncio                 56.152137  Abaixo de 120 km
# 5503               Vila Flores                133.275166   Entre 121 e 228
# 5504           Lindolfo Collor                 48.490606  Abaixo de 120 km
# 5505            Barra do Choça                307.875581   Entre 228 e 358
# 5506     Santa Maria do Herval                 63.693160  Abaixo de 120 km
#
# [5507 rows x 3 columns]

# %%
df
# Out:
#                      Município  UF  Área (km²)  Densidade demográfica, 2000  \
# 0                        Jutaí  AM     69857.4                          0.3
# 1     São Gabriel da Cachoeira  AM    109669.0                          0.3
# 2         Formosa do Rio Preto  BA     16514.3                          1.1
# 3                      Miranda  MS      5494.5                          4.2
# 4      Santa Vitória do Palmar  RS      5242.7                          6.4
# ...                        ...  ..         ...                          ...
# 5502     São José do Hortêncio  RS        64.5                         52.4
# 5503               Vila Flores  RS       125.0                         24.7
# 5504           Lindolfo Collor  RS        31.8                        142.9
# 5505            Barra do Choça  BA       781.3                         52.2
# 5506     Santa Maria do Herval  RS       132.6                         44.4
#
#       Distância à capital (km)  Esperança de vida ao nascer, 2000  \
# 0                   749.232205                              61.25
# 1                   851.225150                              68.60
# 2                   756.981922                              64.30
# 3                   181.846641                              65.05
# 4                   436.821147                              68.63
# ...                        ...                                ...
# 5502                 56.152137                              76.82
# 5503                133.275166                              75.51
# 5504                 48.490606                              75.81
# 5505                307.875581                              63.50
# 5506                 63.693160                              75.81
#
#       Mortalidade até um ano de idade, 2000  Taxa de fecundidade total, 2000  \
# 0                                     63.34                             5.74
# 1                                     34.20                             3.21
# 2                                     44.73                             3.49
# 3                                     41.64                             3.11
# 4                                     24.70                             2.85
# ...                                     ...                              ...
# 5502                                   8.37                             2.18
# 5503                                  10.45                             2.01
# 5504                                   9.96                             2.26
# 5505                                  47.63                             3.26
# 5506                                   9.96                             2.17
#
#       Percentual de pessoas de 25 anos ou mais analfabetas, 2000  \
# 0                                                 50.62
# 1                                                 33.99
# 2                                                 40.20
# 3                                                 23.02
# 4                                                 10.70
# ...                                                 ...
# 5502                                               3.15
# 5503                                               6.00
# 5504                                               4.60
# 5505                                              49.27
# 5506                                               3.85
#
#       Renda per Capita, 2000  ...  Taxa bruta de freqüência à escola, 2000  \
# 0                      60.79  ...                                    51.33
# 1                     106.61  ...                                    68.38
# 2                     117.52  ...                                    79.18
# 3                     248.19  ...                                    76.35
# 4                     406.43  ...                                    85.84
# ...                      ...  ...                                      ...
# 5502                  250.83  ...                                    71.58
# 5503                  246.57  ...                                    86.00
# 5504                  240.11  ...                                    72.43
# 5505                   71.75  ...                                    75.63
# 5506                  247.76  ...                                    69.68
#
#       Taxa de alfabetização, 2000  \
# 0                           54.90
# 1                           76.85
# 2                           67.70
# 3                           83.40
# 4                           91.11
# ...                           ...
# 5502                        97.31
# 5503                        94.81
# 5504                        95.62
# 5505                        64.33
# 5506                        96.78
#
#       Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000  \
# 0                                                  2.08
# 1                                                  3.90
# 2                                                  2.90
# 3                                                  4.15
# 4                                                  5.70
# ...                                                 ...
# 5502                                               5.14
# 5503                                               5.31
# 5504                                               4.74
# 5505                                               1.75
# 5506                                               4.88
#
#       População de 25 anos ou mais de idade, 2000  \
# 0                                            6210
# 1                                           11783
# 2                                            6935
# 3                                           10601
# 4                                           18638
# ...                                           ...
# 5502                                         2043
# 5503                                         1901
# 5504                                         2255
# 5505                                        17090
# 5506                                         3496
#
#       População de 65 anos ou mais de idade, 2000  População total, 2000  \
# 0                                             466                  22500
# 1                                            1096                  29947
# 2                                             777                  18288
# 3                                            1141                  23007
# 4                                            2605                  33304
# ...                                           ...                    ...
# 5502                                          296                   3387
# 5503                                          285                   3086
# 5504                                          173                   4414
# 5505                                         1693                  40818
# 5506                                          428                   5891
#
#       População urbana, 2000  População rural, 2000      Faixa_renda  \
# 0                       7725                  14775    Abaixo de 100
# 1                      12373                  17574  Entre 100 e 200
# 2                       9381                   8907  Entre 100 e 200
# 3                      12059                  10948  Entre 201 e 300
# 4                      27952                   5352     Acima de 400
# ...                      ...                    ...              ...
# 5502                    2093                   1294  Entre 201 e 300
# 5503                    1045                   2041  Entre 201 e 300
# 5504                    3418                    996  Entre 201 e 300
# 5505                   17721                  23097    Abaixo de 100
# 5506                    4159                   1732  Entre 201 e 300
#
#       Distancia_capital
# 0          Acima de 358
# 1          Acima de 358
# 2          Acima de 358
# 3       Entre 121 e 228
# 4          Acima de 358
# ...                 ...
# 5502   Abaixo de 120 km
# 5503    Entre 121 e 228
# 5504   Abaixo de 120 km
# 5505    Entre 228 e 358
# 5506   Abaixo de 120 km
#
# [5507 rows x 24 columns]

# %% [markdown]
# ## Quantidade de clusters para Renda per Capita

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12))
X = df['Renda per Capita, 2000'].values.reshape(-1,1)

visualizer.fit(X)    # Fit the data to the visualizer
visualizer.poof() ;   # Draw/show/poof the data

# %% [markdown]
# ## Quantidade de clusters para Distancia a capital

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12))
X = df['Distância à capital (km)'].values.reshape(-1,1)

visualizer.fit(X)    # Fit the data to the visualizer
visualizer.poof();    # Draw/show/poof the data

# %%
def number_of_cluster(coluna):
  sse={}
  df_cluster = df[[coluna]]
  for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(df_cluster)
    df_cluster["clusters"] = kmeans.labels_
    sse[k] = kmeans.inertia_
    
  plt.figure(figsize=(10, 5))
  plt.plot(list(sse.keys()), list(sse.values()))
  plt.title("Number of Cluster by Column\n"+coluna)
  plt.xlabel("Number of cluster")
  plt.show()

# %%
def create_cluster(df,coluna, nova_coluna):
  #building 3 clusters for Frequency and adding it to dataframe
  kmeans = KMeans(n_clusters=3)
  kmeans.fit(df[[coluna]])
  df[nova_coluna] = kmeans.predict(df[[coluna]])
  df = order_cluster(nova_coluna, coluna,df,False)

# %% [markdown]
# ## Identificar pelo metodo de Elbow o numero de cluster pela Renda per Capita

# %%
number_of_cluster('Renda per Capita, 2000')

# %%
create_cluster(df,'Renda per Capita, 2000', 'Cluster_Renda' )

# %%
df
# Out:
#                      Município  UF  Área (km²)  Densidade demográfica, 2000  \
# 0                        Jutaí  AM     69857.4                          0.3
# 1     São Gabriel da Cachoeira  AM    109669.0                          0.3
# 2         Formosa do Rio Preto  BA     16514.3                          1.1
# 3                      Miranda  MS      5494.5                          4.2
# 4      Santa Vitória do Palmar  RS      5242.7                          6.4
# ...                        ...  ..         ...                          ...
# 5502     São José do Hortêncio  RS        64.5                         52.4
# 5503               Vila Flores  RS       125.0                         24.7
# 5504           Lindolfo Collor  RS        31.8                        142.9
# 5505            Barra do Choça  BA       781.3                         52.2
# 5506     Santa Maria do Herval  RS       132.6                         44.4
#
#       Distância à capital (km)  Esperança de vida ao nascer, 2000  \
# 0                   749.232205                              61.25
# 1                   851.225150                              68.60
# 2                   756.981922                              64.30
# 3                   181.846641                              65.05
# 4                   436.821147                              68.63
# ...                        ...                                ...
# 5502                 56.152137                              76.82
# 5503                133.275166                              75.51
# 5504                 48.490606                              75.81
# 5505                307.875581                              63.50
# 5506                 63.693160                              75.81
#
#       Mortalidade até um ano de idade, 2000  Taxa de fecundidade total, 2000  \
# 0                                     63.34                             5.74
# 1                                     34.20                             3.21
# 2                                     44.73                             3.49
# 3                                     41.64                             3.11
# 4                                     24.70                             2.85
# ...                                     ...                              ...
# 5502                                   8.37                             2.18
# 5503                                  10.45                             2.01
# 5504                                   9.96                             2.26
# 5505                                  47.63                             3.26
# 5506                                   9.96                             2.17
#
#       Percentual de pessoas de 25 anos ou mais analfabetas, 2000  \
# 0                                                 50.62
# 1                                                 33.99
# 2                                                 40.20
# 3                                                 23.02
# 4                                                 10.70
# ...                                                 ...
# 5502                                               3.15
# 5503                                               6.00
# 5504                                               4.60
# 5505                                              49.27
# 5506                                               3.85
#
#       Renda per Capita, 2000  ...  Taxa de alfabetização, 2000  \
# 0                      60.79  ...                        54.90
# 1                     106.61  ...                        76.85
# 2                     117.52  ...                        67.70
# 3                     248.19  ...                        83.40
# 4                     406.43  ...                        91.11
# ...                      ...  ...                          ...
# 5502                  250.83  ...                        97.31
# 5503                  246.57  ...                        94.81
# 5504                  240.11  ...                        95.62
# 5505                   71.75  ...                        64.33
# 5506                  247.76  ...                        96.78
#
#       Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000  \
# 0                                                  2.08
# 1                                                  3.90
# 2                                                  2.90
# 3                                                  4.15
# 4                                                  5.70
# ...                                                 ...
# 5502                                               5.14
# 5503                                               5.31
# 5504                                               4.74
# 5505                                               1.75
# 5506                                               4.88
#
#       População de 25 anos ou mais de idade, 2000  \
# 0                                            6210
# 1                                           11783
# 2                                            6935
# 3                                           10601
# 4                                           18638
# ...                                           ...
# 5502                                         2043
# 5503                                         1901
# 5504                                         2255
# 5505                                        17090
# 5506                                         3496
#
#       População de 65 anos ou mais de idade, 2000  População total, 2000  \
# 0                                             466                  22500
# 1                                            1096                  29947
# 2                                             777                  18288
# 3                                            1141                  23007
# 4                                            2605                  33304
# ...                                           ...                    ...
# 5502                                          296                   3387
# 5503                                          285                   3086
# 5504                                          173                   4414
# 5505                                         1693                  40818
# 5506                                          428                   5891
#
#       População urbana, 2000  População rural, 2000      Faixa_renda  \
# 0                       7725                  14775    Abaixo de 100
# 1                      12373                  17574  Entre 100 e 200
# 2                       9381                   8907  Entre 100 e 200
# 3                      12059                  10948  Entre 201 e 300
# 4                      27952                   5352     Acima de 400
# ...                      ...                    ...              ...
# 5502                    2093                   1294  Entre 201 e 300
# 5503                    1045                   2041  Entre 201 e 300
# 5504                    3418                    996  Entre 201 e 300
# 5505                   17721                  23097    Abaixo de 100
# 5506                    4159                   1732  Entre 201 e 300
#
#       Distancia_capital  Cluster_Renda
# 0          Acima de 358              0
# 1          Acima de 358              0
# 2          Acima de 358              0
# 3       Entre 121 e 228              2
# 4          Acima de 358              1
# ...                 ...            ...
# 5502   Abaixo de 120 km              2
# 5503    Entre 121 e 228              2
# 5504   Abaixo de 120 km              2
# 5505    Entre 228 e 358              0
# 5506   Abaixo de 120 km              2
#
# [5507 rows x 25 columns]

# %%
df[['Renda per Capita, 2000', 'Cluster_Renda', 'Faixa_renda']]
# Out:
#       Renda per Capita, 2000  Cluster_Renda      Faixa_renda
# 0                      60.79              0    Abaixo de 100
# 1                     106.61              0  Entre 100 e 200
# 2                     117.52              0  Entre 100 e 200
# 3                     248.19              2  Entre 201 e 300
# 4                     406.43              1     Acima de 400
# ...                      ...            ...              ...
# 5502                  250.83              2  Entre 201 e 300
# 5503                  246.57              2  Entre 201 e 300
# 5504                  240.11              2  Entre 201 e 300
# 5505                   71.75              0    Abaixo de 100
# 5506                  247.76              2  Entre 201 e 300
#
# [5507 rows x 3 columns]

# %% [markdown]
# ## Identificar pelo metodo de Elbow o numero de cluster pela Distancia a Capital

# %%
number_of_cluster('Distância à capital (km)')

# %%
create_cluster(df,'Distância à capital (km)', 'Cluster_Distancia' )

# %%
df
# Out:
#                      Município  UF  Área (km²)  Densidade demográfica, 2000  \
# 0                        Jutaí  AM     69857.4                          0.3
# 1     São Gabriel da Cachoeira  AM    109669.0                          0.3
# 2         Formosa do Rio Preto  BA     16514.3                          1.1
# 3                      Miranda  MS      5494.5                          4.2
# 4      Santa Vitória do Palmar  RS      5242.7                          6.4
# ...                        ...  ..         ...                          ...
# 5502     São José do Hortêncio  RS        64.5                         52.4
# 5503               Vila Flores  RS       125.0                         24.7
# 5504           Lindolfo Collor  RS        31.8                        142.9
# 5505            Barra do Choça  BA       781.3                         52.2
# 5506     Santa Maria do Herval  RS       132.6                         44.4
#
#       Distância à capital (km)  Esperança de vida ao nascer, 2000  \
# 0                   749.232205                              61.25
# 1                   851.225150                              68.60
# 2                   756.981922                              64.30
# 3                   181.846641                              65.05
# 4                   436.821147                              68.63
# ...                        ...                                ...
# 5502                 56.152137                              76.82
# 5503                133.275166                              75.51
# 5504                 48.490606                              75.81
# 5505                307.875581                              63.50
# 5506                 63.693160                              75.81
#
#       Mortalidade até um ano de idade, 2000  Taxa de fecundidade total, 2000  \
# 0                                     63.34                             5.74
# 1                                     34.20                             3.21
# 2                                     44.73                             3.49
# 3                                     41.64                             3.11
# 4                                     24.70                             2.85
# ...                                     ...                              ...
# 5502                                   8.37                             2.18
# 5503                                  10.45                             2.01
# 5504                                   9.96                             2.26
# 5505                                  47.63                             3.26
# 5506                                   9.96                             2.17
#
#       Percentual de pessoas de 25 anos ou mais analfabetas, 2000  \
# 0                                                 50.62
# 1                                                 33.99
# 2                                                 40.20
# 3                                                 23.02
# 4                                                 10.70
# ...                                                 ...
# 5502                                               3.15
# 5503                                               6.00
# 5504                                               4.60
# 5505                                              49.27
# 5506                                               3.85
#
#       Renda per Capita, 2000  ...  \
# 0                      60.79  ...
# 1                     106.61  ...
# 2                     117.52  ...
# 3                     248.19  ...
# 4                     406.43  ...
# ...                      ...  ...
# 5502                  250.83  ...
# 5503                  246.57  ...
# 5504                  240.11  ...
# 5505                   71.75  ...
# 5506                  247.76  ...
#
#       Média de anos de estudo das pessoas de 25 anos ou mais de idade, 2000  \
# 0                                                  2.08
# 1                                                  3.90
# 2                                                  2.90
# 3                                                  4.15
# 4                                                  5.70
# ...                                                 ...
# 5502                                               5.14
# 5503                                               5.31
# 5504                                               4.74
# 5505                                               1.75
# 5506                                               4.88
#
#       População de 25 anos ou mais de idade, 2000  \
# 0                                            6210
# 1                                           11783
# 2                                            6935
# 3                                           10601
# 4                                           18638
# ...                                           ...
# 5502                                         2043
# 5503                                         1901
# 5504                                         2255
# 5505                                        17090
# 5506                                         3496
#
#       População de 65 anos ou mais de idade, 2000  População total, 2000  \
# 0                                             466                  22500
# 1                                            1096                  29947
# 2                                             777                  18288
# 3                                            1141                  23007
# 4                                            2605                  33304
# ...                                           ...                    ...
# 5502                                          296                   3387
# 5503                                          285                   3086
# 5504                                          173                   4414
# 5505                                         1693                  40818
# 5506                                          428                   5891
#
#       População urbana, 2000  População rural, 2000      Faixa_renda  \
# 0                       7725                  14775    Abaixo de 100
# 1                      12373                  17574  Entre 100 e 200
# 2                       9381                   8907  Entre 100 e 200
# 3                      12059                  10948  Entre 201 e 300
# 4                      27952                   5352     Acima de 400
# ...                      ...                    ...              ...
# 5502                    2093                   1294  Entre 201 e 300
# 5503                    1045                   2041  Entre 201 e 300
# 5504                    3418                    996  Entre 201 e 300
# 5505                   17721                  23097    Abaixo de 100
# 5506                    4159                   1732  Entre 201 e 300
#
#       Distancia_capital  Cluster_Renda  Cluster_Distancia
# 0          Acima de 358              0                  2
# 1          Acima de 358              0                  2
# 2          Acima de 358              0                  2
# 3       Entre 121 e 228              2                  0
# 4          Acima de 358              1                  2
# ...                 ...            ...                ...
# 5502   Abaixo de 120 km              2                  0
# 5503    Entre 121 e 228              2                  0
# 5504   Abaixo de 120 km              2                  0
# 5505    Entre 228 e 358              0                  1
# 5506   Abaixo de 120 km              2                  0
#
# [5507 rows x 26 columns]

# %%
df[['Distância à capital (km)', 'Cluster_Distancia','Distancia_capital']]
# Out:
#       Distância à capital (km)  Cluster_Distancia Distancia_capital
# 0                   749.232205                  2      Acima de 358
# 1                   851.225150                  2      Acima de 358
# 2                   756.981922                  2      Acima de 358
# 3                   181.846641                  0   Entre 121 e 228
# 4                   436.821147                  2      Acima de 358
# ...                        ...                ...               ...
# 5502                 56.152137                  0  Abaixo de 120 km
# 5503                133.275166                  0   Entre 121 e 228
# 5504                 48.490606                  0  Abaixo de 120 km
# 5505                307.875581                  1   Entre 228 e 358
# 5506                 63.693160                  0  Abaixo de 120 km
#
# [5507 rows x 3 columns]

# %%
df.Cluster_Distancia.value_counts()
# Out:
# 0    2431
# 1    2097
# 2     979
# Name: Cluster_Distancia, dtype: int64

# %%
df.Cluster_Renda.value_counts()
# Out:
# 0    2611
# 2    2215
# 1     681
# Name: Cluster_Renda, dtype: int64

# %%
df[['Município', 'Cluster_Renda', "Faixa_renda", 'Cluster_Distancia', 'Distancia_capital']]
# Out:
#                      Município  Cluster_Renda      Faixa_renda  \
# 0                        Jutaí              0    Abaixo de 100
# 1     São Gabriel da Cachoeira              0  Entre 100 e 200
# 2         Formosa do Rio Preto              0  Entre 100 e 200
# 3                      Miranda              2  Entre 201 e 300
# 4      Santa Vitória do Palmar              1     Acima de 400
# ...                        ...            ...              ...
# 5502     São José do Hortêncio              2  Entre 201 e 300
# 5503               Vila Flores              2  Entre 201 e 300
# 5504           Lindolfo Collor              2  Entre 201 e 300
# 5505            Barra do Choça              0    Abaixo de 100
# 5506     Santa Maria do Herval              2  Entre 201 e 300
#
#       Cluster_Distancia Distancia_capital
# 0                     2      Acima de 358
# 1                     2      Acima de 358
# 2                     2      Acima de 358
# 3                     0   Entre 121 e 228
# 4                     2      Acima de 358
# ...                 ...               ...
# 5502                  0  Abaixo de 120 km
# 5503                  0   Entre 121 e 228
# 5504                  0  Abaixo de 120 km
# 5505                  1   Entre 228 e 358
# 5506                  0  Abaixo de 120 km
#
# [5507 rows x 5 columns]
